# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Social Media Engagement Dataset.csv")

# %% [markdown]
# # Show basic info

# %%
print("Dataset Preview:")
print(df.head())

print("\nDataset Info:")
print(df.info())
# Out:
# Dataset Preview:
#         post_id            timestamp day_of_week   platform        user_id  \
# 0  kcqbs6hxybia  2024-12-09 11:26:15      Monday  Instagram  user_52nwb0a6
# 1  vkmervg4ioos  2024-07-28 19:59:26      Sunday    Twitter  user_ucryct98
# 2  memhx4o1x6yu  2024-11-23 14:00:12    Saturday     Reddit  user_7rrev126
# 3  bhyo6piijqt9  2024-09-16 04:35:25      Monday    YouTube  user_4mxuq0ax
# 4  c9dkiomowakt  2024-09-05 21:03:01    Thursday    Twitter  user_l1vpox2k
#
#                location language  \
# 0  Melbourne, Australia       pt
# 1          Tokyo, Japan       ru
# 2        Beijing, China       ru
# 3        Lagos, Nigeria       en
# 4       Berlin, Germany       hi
#
#                                         text_content  \
# 0  Just tried the Chromebook from Google. Best pu...
# 1  Just saw an ad for Microsoft Surface Laptop du...
# 2  What's your opinion about Nike's Epic React?  ...
# 3  Bummed out with my new Diet Pepsi from Pepsi! ...
# 4  Just tried the Corolla from Toyota. Absolutely...
#
#                    hashtags                        mentions  ...  \
# 0                     #Food                             NaN  ...
# 1          #MustHave, #Food     @CustomerService, @BrandCEO  ...
# 2  #Promo, #Food, #Trending                             NaN  ...
# 3    #Reviews, #Sustainable      @StyleGuide, @BrandSupport  ...
# 4          #Health, #Travel  @BrandSupport, @InfluencerName  ...
#
#   comments_count impressions  engagement_rate brand_name    product_name  \
# 0            701       18991          0.19319     Google      Chromebook
# 1            359       52764          0.05086  Microsoft  Surface Laptop
# 2            643        8887          0.45425       Nike      Epic React
# 3            743        6696          0.42293      Pepsi      Diet Pepsi
# 4            703       47315          0.08773     Toyota         Corolla
#
#       campaign_name  campaign_phase  user_past_sentiment_avg  \
# 0       BlackFriday          Launch                   0.0953
# 1      PowerRelease     Post-Launch                   0.1369
# 2       BlackFriday     Post-Launch                   0.2855
# 3        LaunchWave          Launch                  -0.2094
# 4  LocalTouchpoints          Launch                   0.6867
#
#    user_engagement_growth  buzz_change_rate
# 0                 -0.3672              19.1
# 1                 -0.4510             -42.6
# 2                 -0.4112              17.4
# 3                 -0.0167              -5.5
# 4                  0.0807              38.8
#
# [5 rows x 28 columns]
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   post_id                  12000 non-null  object
#  1   timestamp                12000 non-null  object
#  2   day_of_week              12000 non-null  object
#  3   platform                 12000 non-null  object
#  4   user_id                  12000 non-null  object
#  5   location                 12000 non-null  object
#  6   language                 12000 non-null  object
#  7   text_content             12000 non-null  object
#  8   hashtags                 12000 non-null  object
#  9   mentions                 8059 non-null   object
#  10  keywords                 12000 non-null  object
#  11  topic_category           12000 non-null  object
#  12  sentiment_score          12000 non-null  float64
#  13  sentiment_label          12000 non-null  object
#  14  emotion_type             12000 non-null  object
#  15  toxicity_score           12000 non-null  float64
#  16  likes_count              12000 non-null  int64
#  17  shares_count             12000 non-null  int64
#  18  comments_count           12000 non-null  int64
#  19  impressions              12000 non-null  int64
#  20  engagement_rate          12000 non-null  float64
#  21  brand_name               12000 non-null  object
#  22  product_name             12000 non-null  object
#  23  campaign_name            12000 non-null  object
#  24  campaign_phase           12000 non-null  object
#  25  user_past_sentiment_avg  12000 non-null  float64
#  26  user_engagement_growth   12000 non-null  float64
#  27  buzz_change_rate         12000 non-null  float64
# dtypes: float64(6), int64(4), object(18)
# memory usage: 2.6+ MB
# None

# %%
print(df.columns)
# Out:
# Index(['post_id', 'timestamp', 'day_of_week', 'platform', 'user_id',
#        'location', 'language', 'text_content', 'hashtags', 'mentions',
#        'keywords', 'topic_category', 'sentiment_score', 'sentiment_label',
#        'emotion_type', 'toxicity_score', 'likes_count', 'shares_count',
#        'comments_count', 'impressions', 'engagement_rate', 'brand_name',
#        'product_name', 'campaign_name', 'campaign_phase',
#        'user_past_sentiment_avg', 'user_engagement_growth',
#        'buzz_change_rate'],
#       dtype='object')

# %% [markdown]
# # 2. Analyze likes, shares, comments

# %%
print("\nBasic Statistics:")
print(df[['likes_count', 'shares_count', 'comments_count']].describe())
# Out:
# Basic Statistics:
#        likes_count  shares_count  comments_count
# count  12000.00000  12000.000000     12000.00000
# mean    2490.72025   1007.167167       504.34575
# std     1441.53253    575.072282       288.68416
# min        0.00000      0.000000         0.00000
# 25%     1236.00000    510.000000       253.00000
# 50%     2496.00000   1018.000000       503.00000
# 75%     3723.25000   1501.000000       755.00000
# max     5000.00000   2000.000000      1000.00000

# %% [markdown]
# # 3. Identify most engaging posts

# %%
 df['Total_Engagement'] = df['likes_count'] + df['shares_count'] + df['comments_count']
top_posts = df.sort_values(by='Total_Engagement', ascending=False).head(10)

print("\nTop 10 Most Engaging Posts:")
print(top_posts)
# Out:
# Top 10 Most Engaging Posts:
#             post_id            timestamp day_of_week   platform  \
# 459    7v5a8zyj4gw5  2024-06-23 09:31:00      Sunday    YouTube
# 11947  ycjj5zzt7mvx  2025-02-19 05:57:35   Wednesday  Instagram
# 8925   3dh1ecglz4bd  2024-06-04 16:23:20     Tuesday     Reddit
# 3075   wo7py9aljg3t  2025-04-28 20:25:50      Monday     Reddit
# 1770   gmoeib832zbs  2025-01-24 10:39:09      Friday   Facebook
# 6899   5kvuyvf38nqx  2024-06-09 14:59:35      Sunday    YouTube
# 11154  pvfl3d8hj7jd  2024-05-15 14:02:32   Wednesday  Instagram
# 4093   tdgjjylpua20  2024-06-02 14:39:08      Sunday    YouTube
# 3881   tne7s3o4l4wd  2024-10-30 11:45:55   Wednesday  Instagram
# 6398   kwt9yuwjsw74  2024-12-28 17:25:41    Saturday    Twitter
#
#              user_id            location language  \
# 459    user_qbclaspk  Seoul, South Korea       ru
# 11947  user_3w27ggio          London, UK       ja
# 8925   user_np966onv     Berlin, Germany       es
# 3075   user_50qjuqdj   São Paulo, Brazil       pt
# 1770   user_kk1decwg     Shanghai, China       hi
# 6899   user_n6p8x5xw   Vancouver, Canada       pt
# 11154  user_jwq9kwt4       Madrid, Spain       ja
# 4093   user_j2o4po42       Paris, France       zh
# 3881   user_ix1d6h8j          Dubai, UAE       de
# 6398   user_oa2wz7nx   Vancouver, Canada       hi
#
#                                             text_content  \
# 459    How do I fix about Samsung's Neo QLED TV? @Bra...
# 11947  Coca-Cola HolidaySpecial is fantastic! Can't w...
# 8925   Has anyone else experienced connectivity issue...
# 3075   Attended the Nike LaunchWave event yesterday. ...
# 1770   Should I upgrade about Apple's iPhone 15? @Tec...
# 6899   Just tried the Sprite from Coca-Cola. Worth ev...
# 11154  Just tried the Eero WiFi from Amazon. Highly r...
# 4093   Comparing Adidas Samba to the competition. Had...
# 3881   Just unboxed my new Coke Zero from Coca-Cola. ...
# 6398   What's your opinion about Microsoft's Xbox Ser...
#
#                                        hashtags  \
# 459                           #Discount, #Promo
# 11947              #TrendAlert, #Reviews, #Food
# 8925                         #Tech, #Innovation
# 3075   #NewRelease, #Affordable, #ProductLaunch
# 1770                                   #Fashion
# 6899                      #MustHave, #BestValue
# 11154        #Eco, #Lifestyle, #CustomerService
# 4093                            #Limited, #Food
# 3881              #Food, #NewRelease, #Trending
# 6398                           #CustomerService
#
#                              mentions  ... impressions engagement_rate  \
# 459        @BrandSupport, @StyleGuide  ...       24553         0.32175
# 11947                @CustomerService  ...       74605         0.10579
# 8925                  @InfluencerName  ...       89017         0.08781
# 3075                              NaN  ...       65545         0.11889
# 1770        @TechHelp, @CelebrityName  ...       39541         0.19635
# 6899           @TechHelp, @ReviewSite  ...       19062         0.40683
# 11154                     @ReviewSite  ...       16706         0.46318
# 4093   @MarketingTeam, @RetailSupport  ...       74939         0.10305
# 3881                     @ProductTeam  ...       35180         0.21921
# 6398   @IndustryExpert, @BrandSupport  ...       29809         0.25780
#
#        brand_name   product_name    campaign_name  campaign_phase  \
# 459       Samsung    Neo QLED TV      BlackFriday      Pre-Launch
# 11947   Coca-Cola      Coke Zero     BackToSchool     Post-Launch
# 8925       Toyota         Tundra      CyberMonday          Launch
# 3075         Nike     Epic React   NextGeneration      Pre-Launch
# 1770        Apple      iPhone 15  ValentinesDeals      Pre-Launch
# 6899    Coca-Cola         Sprite    ReferralBonus      Pre-Launch
# 11154      Amazon      Eero WiFi      CyberMonday      Pre-Launch
# 4093       Adidas          Samba  SpringBlast2025          Launch
# 3881    Coca-Cola      Coke Zero    WinterWonders     Post-Launch
# 6398    Microsoft  Xbox Series X      InnovationX      Pre-Launch
#
#        user_past_sentiment_avg  user_engagement_growth  buzz_change_rate  \
# 459                    -0.7982                 -0.1077              95.0
# 11947                   0.8372                  0.0011              91.1
# 8925                    0.3292                  0.3187             -65.1
# 3075                    0.0610                  0.3124              60.7
# 1770                    0.8004                 -0.1180             -71.3
# 6899                   -0.2511                 -0.3105             -56.6
# 11154                   0.2950                  0.3854              97.5
# 4093                   -0.6956                  0.4620              81.7
# 3881                   -0.3227                  0.2036             -13.5
# 6398                    0.7110                  0.4785              50.1
#
#        Total_Engagement
# 459                7900
# 11947              7893
# 8925               7817
# 3075               7793
# 1770               7764
# 6899               7755
# 11154              7738
# 4093               7723
# 3881               7712
# 6398               7685
#
# [10 rows x 29 columns]

# %% [markdown]
# # 4. Visualization

# %% [markdown]
# ### i. Likes, Shares, Comments Distribution

# %%
plt.figure()
df[['likes_count', 'shares_count', 'comments_count']].hist(bins=20)
plt.suptitle("Distribution of Engagement Metrics")
plt.show()

# %% [markdown]
# ### ii. Engagement Comparison (Bar Chart)

# %%
plt.figure()
avg_values = df[['likes_count', 'shares_count', 'comments_count']].mean()
avg_values.plot(kind='bar')
plt.title("Average Engagement Metrics")
plt.xlabel("Metric")
plt.ylabel("Average Value")
plt.show()

# %% [markdown]
# ### iii. Top Posts Visualization

# %%
plt.figure()
top_posts['Total_Engagement'].plot(kind='bar')
plt.title("Top 10 Most Engaging Posts")
plt.xlabel("Post Index")
plt.ylabel("Engagement")
plt.show()

# %% [markdown]
# ### iv. Correlation Heatmap

# %%
plt.figure()
corr = df[['likes_count', 'shares_count', 'comments_count']].corr()
print("\nCorrelation Matrix:\n", corr)
# Out:
# Correlation Matrix:
#                  likes_count  shares_count  comments_count
# likes_count        1.000000      0.002741        0.007044
# shares_count       0.002741      1.000000        0.024406
# comments_count     0.007044      0.024406        1.000000

# %% [markdown]
# # 5. Insights

# %%
print("\nINSIGHTS:")

print(f"- Average Likes: {df['likes_count'].mean():.2f}")
print(f"- Average Shares: {df['shares_count'].mean():.2f}")
print(f"- Average Comments: {df['comments_count'].mean():.2f}")

most_liked = df.loc[df['likes_count'].idxmax()]
print("\nMost Liked Post:")
print(most_liked)

most_shared = df.loc[df['shares_count'].idxmax()]
print("\nMost Shared Post:")
print(most_shared)

most_commented = df.loc[df['comments_count'].idxmax()]
print("\nMost Commented Post:")
print(most_commented)
# Out:
# INSIGHTS:
# - Average Likes: 2490.72
# - Average Shares: 1007.17
# - Average Comments: 504.35
#
# Most Liked Post:
# post_id                                                         87gq6xrd3ykv
# timestamp                                                2025-01-13 22:40:17
# day_of_week                                                           Monday
# platform                                                              Reddit
# user_id                                                        user_sq4ch5k2
# location                                                        Chicago, USA
# language                                                                  en
# text_content               My one year review of Adidas Samba: Worth ever...
# hashtags                                                            #Quality
# mentions                                                        @ProductTeam
# keywords                             luxury, premium, amazing, disappointing
# topic_category                                                       Pricing
# sentiment_score                                                       0.9257
# sentiment_label                                                     Positive
# emotion_type                                                         Excited
# toxicity_score                                                        0.8718
# likes_count                                                             5000
# shares_count                                                             824
# comments_count                                                           401
# impressions                                                            69646
# engagement_rate                                                      0.08938
# brand_name                                                            Adidas
# product_name                                                           Samba
# campaign_name                                                 NextGeneration
# campaign_phase                                                    Pre-Launch
# user_past_sentiment_avg                                              -0.4321
# user_engagement_growth                                               -0.4779
# buzz_change_rate                                                        -8.6
# Total_Engagement                                                        6225
# Name: 1166, dtype: object
#
# Most Shared Post:
# post_id                                                         euvr0r10wrj6
# timestamp                                                2025-04-26 04:54:48
# day_of_week                                                         Saturday
# platform                                                            Facebook
# user_id                                                        user_wssjsdac
# location                                          Johannesburg, South Africa
# language                                                                  pt
# text_content               Just unboxed my new Zoom Pegasus from Nike. Wo...
# hashtags                                         #Sustainable, #SpecialOffer
# mentions                                                                 NaN
# keywords                                                      fast, outdated
# topic_category                                                       Returns
# sentiment_score                                                      -0.2109
# sentiment_label                                                     Negative
# emotion_type                                                        Confused
# toxicity_score                                                        0.4376
# likes_count                                                              453
# shares_count                                                            2000
# comments_count                                                           408
# impressions                                                            97344
# engagement_rate                                                      0.02939
# brand_name                                                              Nike
# product_name                                                    Zoom Pegasus
# campaign_name                                                 NextGeneration
# campaign_phase                                                        Launch
# user_past_sentiment_avg                                              -0.8892
# user_engagement_growth                                               -0.3807
# buzz_change_rate                                                        91.4
# Total_Engagement                                                        2861
# Name: 202, dtype: object
#
# Most Commented Post:
# post_id                                                         6viq2n7poav6
# timestamp                                                2025-03-22 01:38:46
# day_of_week                                                         Saturday
# platform                                                            Facebook
# user_id                                                        user_539vo4v4
# location                                              Rio de Janeiro, Brazil
# language                                                                  ar
# text_content               Adidas SustainableFuture is disappointing! Can...
# hashtags                                                               #Deal
# mentions                                         @ReviewSite, @MarketingTeam
# keywords                                            experience, eco-friendly
# topic_category                                                     Marketing
# sentiment_score                                                       -0.588
# sentiment_label                                                     Negative
# emotion_type                                                             Sad
# toxicity_score                                                        0.0963
# likes_count                                                              737
# shares_count                                                             820
# comments_count                                                          1000
# impressions                                                            64605
# engagement_rate                                                      0.03957
# brand_name                                                            Adidas
# product_name                                                       Superstar
# campaign_name                                          DigitalTransformation
# campaign_phase                                                   Post-Launch
# user_past_sentiment_avg                                               0.6622
# user_engagement_growth                                                0.2686
# buzz_change_rate                                                        88.3
# Total_Engagement                                                        2557
# Name: 194, dtype: object

# %%
print(df.columns)
# Out:
# Index(['post_id', 'timestamp', 'day_of_week', 'platform', 'user_id',
#        'location', 'language', 'text_content', 'hashtags', 'mentions',
#        'keywords', 'topic_category', 'sentiment_score', 'sentiment_label',
#        'emotion_type', 'toxicity_score', 'likes_count', 'shares_count',
#        'comments_count', 'impressions', 'engagement_rate', 'brand_name',
#        'product_name', 'campaign_name', 'campaign_phase',
#        'user_past_sentiment_avg', 'user_engagement_growth', 'buzz_change_rate',
#        'Total_Engagement'],
#       dtype='object')

# %%
print("\nTop Posts by Engagement Rate:")
print(df.sort_values(by='engagement_rate', ascending=False).head(5))
# Out:
# Top Posts by Engagement Rate:
#             post_id            timestamp day_of_week   platform  \
# 2880   67d6fsv09zzv  2024-08-21 00:02:02   Wednesday     Reddit
# 11926  h03dprdsxb4t  2024-11-05 00:10:55     Tuesday  Instagram
# 719    u50pnlesq1y8  2024-12-30 21:31:52      Monday     Reddit
# 10917  h4btj68pyn9j  2024-09-28 14:22:43    Saturday    YouTube
# 7967   k508grdqqbne  2025-02-07 18:46:29      Friday    YouTube
#
#              user_id         location language  \
# 2880   user_odj3nlo2    Paris, France       hi
# 11926  user_3us7ozg2  Shanghai, China       es
# 719    user_1r1zn4lc       London, UK       en
# 10917  user_grb4vql7    Paris, France       zh
# 7967   user_k9fjjzk5      Rome, Italy       pt
#
#                                             text_content  \
# 2880   Just unboxed my new Galaxy S25 from Samsung. M...
# 11926  Just tried the Zoom Pegasus from Nike. Wouldn'...
# 719    What's your opinion about Microsoft's Xbox Eli...
# 10917  Should I upgrade about Microsoft's Surface Duo...
# 7967   Has anyone else experienced connectivity issue...
#
#                       hashtags                      mentions  ... impressions  \
# 2880                #Lifestyle  @IndustryExpert, @ReviewSite  ...         222
# 11926  #NewRelease, #Lifestyle        @StyleGuide, @TechHelp  ...         243
# 719            #Fitness, #Food                     @BrandCEO  ...         160
# 10917                    #Tech        @TechHelp, @ReviewSite  ...         147
# 7967               #NewRelease                           NaN  ...         244
#
#       engagement_rate  brand_name           product_name   campaign_name  \
# 2880         32.21171     Samsung             Galaxy S25    SummerDreams
# 11926        30.43209        Nike           Zoom Pegasus   CustomerFirst
# 719          30.04375   Microsoft  Xbox Elite Controller  NextGeneration
# 10917        26.08163   Microsoft            Surface Duo    SummerDreams
# 7967         24.50409   Coca-Cola                 Sprite      LaunchWave
#
#        campaign_phase  user_past_sentiment_avg  user_engagement_growth  \
# 2880       Pre-Launch                   0.2699                 -0.1049
# 11926     Post-Launch                  -0.8249                  0.2003
# 719        Pre-Launch                   0.4035                 -0.1149
# 10917     Post-Launch                  -0.6631                 -0.3962
# 7967      Post-Launch                   0.0827                  0.2575
#
#        buzz_change_rate  Total_Engagement
# 2880              -69.0              7151
# 11926             -83.2              7395
# 719               -85.8              4807
# 10917             -52.7              3834
# 7967               -7.4              5979
#
# [5 rows x 29 columns]
